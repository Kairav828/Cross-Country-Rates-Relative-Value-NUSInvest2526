# %%
import sys
import os
from pathlib import Path
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import itertools

# -----------------------------------------------------------------------------
# STEP 0: SETUP & LOAD DATA
# -----------------------------------------------------------------------------

data_path = Path("..") / "DATA" / "processed" / "master_df.parquet"

if not data_path.exists():
    print(f"Error: File not found at {data_path}")
else:
    df_master = pd.read_parquet(data_path)
    print(f"Loaded Master Data: {df_master.shape}")
# Out:
# Loaded Master Data: (9514, 41)

# %%
# -----------------------------------------------------------------------------
# STEP 1: PREPARE DATA
# -----------------------------------------------------------------------------

# 1. Filter for Bond Yields only (5Y and 10Y)
target_tenors = ['5Y', '10Y']
cols_to_keep = [
    c for c in df_master.columns 
    if "bond_yields__" in c and any(t in c for t in target_tenors)
]

df_levels = df_master[cols_to_keep].copy()
df_levels = df_levels.ffill()

# 2. Rename columns to be cleaner
df_levels.columns = [c.replace("bond_yields__", "") for c in df_levels.columns]

# 3. Compute daily changes
df_changes = df_levels.diff().dropna(how='all')

print(f"Data ready: {df_changes.shape[1]} assets tracked.")
display(df_changes.head())
# Out:
# Data ready: 10 assets tracked.
#             GTUSD5Y Govt  GTUSD10Y Govt  GTEUR5Y Govt  GTEUR10Y Govt  \
# date
# 1990-01-03         0.064          0.044           NaN            NaN
# 1990-01-04        -0.011         -0.002           NaN            NaN
# 1990-01-05        -0.004          0.012           NaN            NaN
# 1990-01-08         0.011          0.028           NaN            NaN
# 1990-01-09        -0.004         -0.003           NaN            NaN
#
#             GTJPY5Y Govt  GTJPY10Y Govt  GTCNY5Y Govt  GTCNY10Y Govt  \
# date
# 1990-01-03           NaN          0.000           NaN            NaN
# 1990-01-04           NaN          0.109           NaN            NaN
# 1990-01-05           NaN          0.039           NaN            NaN
# 1990-01-08           NaN          0.088           NaN            NaN
# 1990-01-09           NaN          0.169           NaN            NaN
#
#             GTAUD5Y Govt  GTAUD10Y Govt
# date
# 1990-01-03           NaN            NaN
# 1990-01-04           NaN            NaN
# 1990-01-05           NaN            NaN
# 1990-01-08           NaN            NaN
# 1990-01-09           NaN            NaN

# %%
# -----------------------------------------------------------------------------
# STEP 2: ROLLING CORRELATIONS
# -----------------------------------------------------------------------------

windows = [60, 252]
rolling_corrs = {}

for w in windows:
    rolling_corrs[w] = df_changes.rolling(window=w, min_periods=w//2).corr()
    print(f"Calculated {w}-day rolling correlation.")
# Out:
# Calculated 60-day rolling correlation.
# Calculated 252-day rolling correlation.

# %%
# -----------------------------------------------------------------------------
# STEP 3: STABILITY METRICS
# -----------------------------------------------------------------------------

stability_records = []

for tenor in target_tenors:
    # Find all columns for this tenor (e.g., all '10Y' columns)
    tenor_assets = [c for c in df_changes.columns if tenor in c]
    
    # Create unique pairs
    pairs = list(itertools.combinations(tenor_assets, 2))
    
    for asset_a, asset_b in pairs:
        # Extract 252-day correlation
        series_252 = rolling_corrs[252].xs(asset_a, level=1)[asset_b].dropna()
        
        if series_252.empty:
            continue

        stats = {
            'Tenor': tenor,
            'Pair': f"{asset_a.split()[0]} vs {asset_b.split()[0]}",
            'Mean Corr': series_252.mean(),
            'Std Dev': series_252.std(),
            'Stability': (series_252 > 0.4).mean() * 100
        }
        stability_records.append(stats)

# Summary Table
if stability_records:
    stability_df = pd.DataFrame(stability_records)
    stability_df = stability_df.sort_values(by='Stability', ascending=False)
    print("\n--- Correlation Stability ---")
    display(stability_df)
else:
    print("No overlapping data found for any pairs.")
# Out:
# --- Correlation Stability ---
#    Tenor                  Pair  Mean Corr   Std Dev  Stability
# 10   10Y  GTUSD10Y vs GTEUR10Y   0.528264  0.132304  85.756066
# 0     5Y    GTUSD5Y vs GTEUR5Y   0.457458  0.158634  75.812392
# 18   10Y  GTJPY10Y vs GTAUD10Y   0.341768  0.159476  45.353269
# 8     5Y    GTJPY5Y vs GTAUD5Y   0.302395  0.124784  24.875403
# 6     5Y    GTEUR5Y vs GTAUD5Y   0.202535  0.108682   3.987101
# 16   10Y  GTEUR10Y vs GTAUD10Y   0.233087  0.089755   3.298153
# 14   10Y  GTEUR10Y vs GTJPY10Y   0.140928  0.096406   0.888215
# 13   10Y  GTUSD10Y vs GTAUD10Y   0.122460  0.095824   0.762240
# 2     5Y    GTUSD5Y vs GTCNY5Y   0.026534  0.066661   0.000000
# 12   10Y  GTUSD10Y vs GTCNY10Y   0.051395  0.103662   0.000000
# 17   10Y  GTJPY10Y vs GTCNY10Y   0.079580  0.092966   0.000000
# 15   10Y  GTEUR10Y vs GTCNY10Y   0.068821  0.096805   0.000000
# 11   10Y  GTUSD10Y vs GTJPY10Y   0.086527  0.084224   0.000000
# 3     5Y    GTUSD5Y vs GTAUD5Y   0.112287  0.099712   0.000000
# 1     5Y    GTUSD5Y vs GTJPY5Y   0.075912  0.075565   0.000000
# 9     5Y    GTCNY5Y vs GTAUD5Y   0.092768  0.076826   0.000000
# 7     5Y    GTJPY5Y vs GTCNY5Y   0.064574  0.095148   0.000000
# 5     5Y    GTEUR5Y vs GTCNY5Y   0.043376  0.083420   0.000000
# 4     5Y    GTEUR5Y vs GTJPY5Y   0.128123  0.082112   0.000000
# 19   10Y  GTCNY10Y vs GTAUD10Y   0.112953  0.099494   0.000000

# %%
# -----------------------------------------------------------------------------
# STEP 5: VISUALISATION OF PAIRS
# -----------------------------------------------------------------------------

try:
    from adjustText import adjust_text
    HAS_ADJUST_TEXT = True
except ImportError:
    HAS_ADJUST_TEXT = False
    print("'adjustText' not installed. Labels might overlap. Use pip install adjustText")

# Helper to make names readable: "GTUSD10Y Govt" -> "USD10Y"
def clean_ticker(ticker_name):
    return ticker_name.replace("GT", "").replace(" Govt", "")

trader_df = stability_df.copy()
top_pos = trader_df.nlargest(5, 'Mean Corr')
top_neg = trader_df.nsmallest(5, 'Mean Corr')
top_picks = pd.concat([top_pos, top_neg]).sort_values(by='Mean Corr')

# -----------------------------------------------------------------------------
# Plot 1: Bar chart of top pairs
# -----------------------------------------------------------------------------
plt.figure(figsize=(12, 6))

colors = ['red' if x < 0 else 'green' for x in top_picks['Mean Corr']]
clean_labels = [
    f"{clean_ticker(p.split(' vs ')[0])} vs {clean_ticker(p.split(' vs ')[1])}" 
    for p in top_picks['Pair']
]

plt.barh(clean_labels, top_picks['Mean Corr'], color=colors, alpha=0.7)

plt.axvline(0.8, color='green', linestyle=':', label='High Conviction (+0.8)')
plt.axvline(-0.8, color='red', linestyle=':', label='High Inverse (-0.8)')
plt.axvline(0, color='black', linewidth=0.8)

plt.title("Top Candidates for Pairs Trading")
plt.xlabel("Average Correlation")
plt.legend()
plt.tight_layout()
plt.show()

# -----------------------------------------------------------------------------
# Plot 2: Risk vs. reward scatter plot
# -----------------------------------------------------------------------------
plt.figure(figsize=(12, 10))

custom_markers = {"5Y": "o", "10Y": "X"}
sns.scatterplot(
    data=trader_df, 
    x='Mean Corr', 
    y='Std Dev', 
    hue='Tenor', 
    style='Tenor',
    markers=custom_markers, 
    s=150,
    alpha=0.8,
    edgecolor='black'
)

plt.axvspan(0.8, 1.0, ymin=0, ymax=0.3, color='green', alpha=0.1, label='Prime Long Zone')
plt.axvspan(-1.0, -0.8, ymin=0, ymax=0.3, color='red', alpha=0.1, label='Prime Short Zone')

texts = []
for _, row in top_picks.iterrows():
    raw_pair = row['Pair']
    left, right = raw_pair.split(' vs ')
    clean_label = f"{clean_ticker(left)} vs {clean_ticker(right)}"
    
    t = plt.text(
        row['Mean Corr'], 
        row['Std Dev'], 
        clean_label,
        fontsize=9,
        fontweight='bold',
        color='black'
    )
    texts.append(t)

if HAS_ADJUST_TEXT:
    adjust_text(
        texts, 
        arrowprops=dict(arrowstyle='->', color='gray', lw=0.5), 
        expand_points=(1.2, 1.2)
    )

plt.title("Pairs Selection Matrix: Strength vs. Stability")
plt.xlabel("Correlation Strength (Mean)")
plt.ylabel("Instability Risk (Std Dev)")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# -----------------------------------------------------------------------------
# Plot 3: Visualisation of rolling correlation time series of the best pair
# -----------------------------------------------------------------------------
best_pick = top_picks.iloc[-1]
best_pair_full = best_pick['Pair']
tenor = best_pick['Tenor']

clean_name = f"{clean_ticker(best_pair_full.split(' vs ')[0])} vs {clean_ticker(best_pair_full.split(' vs ')[1])}"

code_a, code_b = best_pair_full.split(' vs ')
col_a = next(c for c in df_changes.columns if code_a in c and tenor in c)
col_b = next(c for c in df_changes.columns if code_b in c and tenor in c)
series_252 = rolling_corrs[252].xs(col_a, level=1)[col_b]

plt.figure(figsize=(14, 5))
plt.plot(series_252, color='black', linewidth=1.5, label='252-Day Correlation')
plt.axhline(0.8, color='green', linestyle='--', label='Target Threshold (0.8)')
plt.title(f"Trade Validation: {clean_name} ({tenor})")
plt.ylabel("Rolling Correlation")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# 'adjustText' not installed. Labels might overlap. Use pip install adjustText

# %%
# Purpose:
# Convert rolling correlation time-series into gate-ready summary statistics
# used later for pair eligibility decisions

# Output locations (results ≠ processed data)
RESULTS_DIR = Path("..") / "results"
PLOTS_DIR = Path("..") / "plots"
RESULTS_DIR.mkdir(exist_ok=True)
PLOTS_DIR.mkdir(exist_ok=True)

def corr_summary(corr_series: pd.Series):
    """
    Summarise rolling correlation behaviour for a pair.
    These statistics capture:
    - central tendency (mean)
    - instability (std)
    - stress behaviour (5th percentile)
    - persistence of strong correlation (>0.6, >0.8)
    """
    s = corr_series.dropna()
    if len(s) == 0:
        return None

    return {
        "mean": float(s.mean()),                 # average relationship strength
        "std": float(s.std()),                   # instability of relationship
        "p05": float(np.quantile(s, 0.05)),      # correlation under stress
        "p50": float(np.quantile(s, 0.50)),      # median behaviour
        "pct_gt_06": float((s > 0.6).mean() * 100),  # % time strongly correlated
        "pct_gt_08": float((s > 0.8).mean() * 100),  # % time very strongly correlated
    }

records = []

# Loop by tenor so curve logic remains explicit
for tenor in target_tenors:
    tenor_assets = [c for c in df_changes.columns if tenor in c]
    pairs = list(itertools.combinations(tenor_assets, 2))

    for a, b in pairs:
        # Use 252d window as primary "structural" horizon
        s252 = rolling_corrs[252].xs(a, level=1)[b].dropna()

        out = corr_summary(s252)
        if out is None:
            continue

        records.append({
            "Tenor": tenor,
            "Asset_A": a,
            "Asset_B": b,
            **out
        })

# Final table used directly in Task 6 gate
corr_metrics = (
    pd.DataFrame(records)
      .sort_values(["pct_gt_08", "mean"], ascending=False)
)

out_path = RESULTS_DIR / "rolling_corr_pair_metrics.csv"
corr_metrics.to_csv(out_path, index=False)

print(f"Saved rolling correlation gate metrics → {out_path}")
display(corr_metrics.head(20))
# Out:
# Saved rolling correlation gate metrics → ../results/rolling_corr_pair_metrics.csv
#    Tenor        Asset_A        Asset_B      mean       std       p05  \
# 10   10Y  GTUSD10Y Govt  GTEUR10Y Govt  0.528264  0.132304  0.274261
# 0     5Y   GTUSD5Y Govt   GTEUR5Y Govt  0.457458  0.158634  0.057873
# 18   10Y  GTJPY10Y Govt  GTAUD10Y Govt  0.341768  0.159476  0.004997
# 8     5Y   GTJPY5Y Govt   GTAUD5Y Govt  0.302395  0.124784  0.050333
# 16   10Y  GTEUR10Y Govt  GTAUD10Y Govt  0.233087  0.089755  0.090146
# 6     5Y   GTEUR5Y Govt   GTAUD5Y Govt  0.202535  0.108682  0.056543
# 14   10Y  GTEUR10Y Govt  GTJPY10Y Govt  0.140928  0.096406 -0.013667
# 4     5Y   GTEUR5Y Govt   GTJPY5Y Govt  0.128123  0.082112 -0.026110
# 13   10Y  GTUSD10Y Govt  GTAUD10Y Govt  0.122460  0.095824 -0.019222
# 19   10Y  GTCNY10Y Govt  GTAUD10Y Govt  0.112953  0.099494 -0.048960
# 3     5Y   GTUSD5Y Govt   GTAUD5Y Govt  0.112287  0.099712 -0.055583
# 9     5Y   GTCNY5Y Govt   GTAUD5Y Govt  0.092768  0.076826 -0.023148
# 11   10Y  GTUSD10Y Govt  GTJPY10Y Govt  0.086527  0.084224 -0.039042
# 17   10Y  GTJPY10Y Govt  GTCNY10Y Govt  0.079580  0.092966 -0.059814
# 1     5Y   GTUSD5Y Govt   GTJPY5Y Govt  0.075912  0.075565 -0.054980
# 15   10Y  GTEUR10Y Govt  GTCNY10Y Govt  0.068821  0.096805 -0.083681
# 7     5Y   GTJPY5Y Govt   GTCNY5Y Govt  0.064574  0.095148 -0.078617
# 12   10Y  GTUSD10Y Govt  GTCNY10Y Govt  0.051395  0.103662 -0.108719
# 5     5Y   GTEUR5Y Govt   GTCNY5Y Govt  0.043376  0.083420 -0.084368
# 2     5Y   GTUSD5Y Govt   GTCNY5Y Govt  0.026534  0.066661 -0.078696
#
#          p50  pct_gt_06  pct_gt_08
# 10  0.553614  32.593154        0.0
# 0   0.485384  15.857886        0.0
# 18  0.381354   0.000000        0.0
# 8   0.323919   0.000000        0.0
# 16  0.231940   0.000000        0.0
# 6   0.189638   0.000000        0.0
# 14  0.155879   0.000000        0.0
# 4   0.134292   0.000000        0.0
# 13  0.116655   0.000000        0.0
# 19  0.111721   0.000000        0.0
# 3   0.128054   0.000000        0.0
# 9   0.086862   0.000000        0.0
# 11  0.083662   0.000000        0.0
# 17  0.072151   0.000000        0.0
# 1   0.077626   0.000000        0.0
# 15  0.053577   0.000000        0.0
# 7   0.065363   0.000000        0.0
# 12  0.024715   0.000000        0.0
# 5   0.040956   0.000000        0.0
# 2   0.025508   0.000000        0.0

# %% [markdown]
# ## Note on results
# Strong rolling correlation in yield changes is rare across countries.
# The fact that pct_gt_06 and pct_gt_08 are mostly zero tells us most candidate pairs are not structurally stable, which is exactly why we need clustering and PCA gates before cointegration.
